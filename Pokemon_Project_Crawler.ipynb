# %%
#library

# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import csv

# %%
#get data

# %%
url='https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number'
r=requests.get(url)
r.encoding = 'utf-8'

# %%
#compile data
soup=BeautifulSoup(r.text,"html5lib")

# %%
#create folder
folder = os.path.exists('Pokemon_data')
if not folder:
#如果不存在，則建立新目錄
    os.makedirs('Pokemon_data')

# %%
#create file
f = open("Pokemon_data/" + 'pokemon_data.csv', "a+"
                     #open for writing, appending to the end of the file if it exists
                     #open for updating (reading and writing)
                     #https://docs.python.org/3/library/functions.html
                     , encoding='utf-8')

# %%
#open file and create column names
with open('pokemon_data.csv', 'a', newline='') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerow(['Kdex','Ndex','Name','Type1','Type2','Link',
               'HP','ATK','DEF','SP_ATK','SP_DEF',
               'Damaged Normally by','Weak to','Immue to','Resisant to'])

# %%
#arrange data
counter=0#counter
for i in soup.find('div',{'id':'mw-content-text'}).find_all('tr',{"style":"background:#FFF"}):
    counter=counter+1
    print('Loading...')
    pokemon_data=[]    
    #generate_number
    generate_number=i.find_all('td')[0].text.replace('\n',"")
    print('Kdex: ',generate_number)
    pokemon_data.append(generate_number)
    
    #national_number
    national_number=i.find_all('td')[1].text.replace('\n',"")
    print('Ndex: ',national_number)
    pokemon_data.append(national_number)
    
    #name
    name=i.find('a')['title']
    print('Name: ',name)
    pokemon_data.append(name)
    #type1
    type1=i.find_all('span')[0].text
    print('Type1: ',type1)
    pokemon_data.append(type1)
    
    #type2 if exist
    if len(i.find_all('span'))==2:
        type2=i.find_all('span')[1].text
        print('Type2: ',type2)
        pokemon_data.append(type2)
    else:
        type2='Null'
        print('Type2: ',type2)
        pokemon_data.append(type2)
    #link to specific attr
    link='https://bulbapedia.bulbagarden.net/'+i.find_all('a',
                                                          href=re.compile("^(/wiki/)((?!;)\S)*$"))[1]['href']
    print('Link: ',link)
    pokemon_data.append(link)
    
    
    #get specific attr for a pokemon
    url_pkm=link
    r_pkm=requests.get(url_pkm)
    r_pkm.encoding = 'utf-8'
    soup_pkm=BeautifulSoup(r_pkm.text,"html5lib")
    
    #hp
    hp=soup_pkm.find('tr',{'style':"background: #FF5959; text-align:center"}).find('div',{'style':'float:right'}).text
    print("HP: ",hp) 
    pokemon_data.append(hp)
    #atk
    atk=soup_pkm.find('tr',{'style':"background: #F5AC78; text-align:center"}).find('div',{'style':'float:right'}).text
    print("ATK: ",atk) 
    pokemon_data.append(atk)
    #def
    defense=soup_pkm.find('tr',{'style':"background: #FAE078; text-align:center"}).find('div',{'style':'float:right'}).text
    print("DEF: ",defense)
    pokemon_data.append(defense)
    #sp_atk
    sp_atk=soup_pkm.find('tr',{'style':"background: #9DB7F5; text-align:center"}).find('div',{'style':'float:right'}).text
    print("SP_ATK: ",sp_atk)  
    pokemon_data.append(sp_atk)
    #sp_def
    sp_defense=soup_pkm.find('tr',{'style':"background: #A7DB8D; text-align:center"}).find('div',{'style':'float:right'}).text
    print("SP_DEF: ",sp_defense)
    pokemon_data.append(sp_defense)
    #spd
    spd=soup_pkm.find('tr',{'style':"background: #FA92B2; text-align:center"}).find('div',{'style':'float:right'}).text
    print("SPD: ",spd)
    pokemon_data.append(spd)

    #type_effectiveness
    type_effectiveness=soup_pkm.find('table',{'class':'roundy','width':'100%','align':'center'}) 
    
    #get four dimentions 
    normal=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[1]
    weak=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[2]
    immue=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[3]
    resisant=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[4]
    #create list for each dimention
    normal_lst=[]
    weak_lst=[]
    immue_lst=[]
    resisant_lst=[]
    
    #get data into each list and print
    #Damaged Normally by
    for j in normal.find_all('span',{'style':'display:inline-block;'}):
        normal_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
    print('Damaged Normally by :',normal_lst)
    pokemon_data.append(str(normal_lst))
    
    #Weak to
    for j in weak.find_all('span',{'style':'display:inline-block;'}):
        weak_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
    print('Weak to :',weak_lst)
    pokemon_data.append(str(weak_lst))
    
    #Immue to
    for j in immue.find_all('span',{'style':'display:inline-block;'}):
        immue_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
    print('Immue to :',immue_lst)
    pokemon_data.append(str(immue_lst))
    
    #Resisant to
    for j in resisant.find_all('span',{'style':'display:inline-block;'}):
        resisant_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
    print('Resisant to :',resisant_lst)
    pokemon_data.append(str(resisant_lst))
    
#writting data    
    
    with open('pokemon_data.csv', 'a', newline='') as file:
        writer = csv.writer(file, delimiter=',')
        writer.writerow(pokemon_data)
    
    print('Writting...')
    print('Done!!!')
    print('==============================================================================\n')
#counter for testing     
    #if counter ==10:
    #    break
    #else:
    #    continue
# Out:
# Loading...
# Kdex:   #001
# Ndex:   #001
# Name:  Bulbasaur
# Type1:  Grass
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Bulbasaur_(Pok%C3%A9mon)
# HP:  45
# ATK:  49
# DEF:  49
# SP_ATK:  65
# SP_DEF:  65
# SPD:  45
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #002
# Ndex:   #002
# Name:  Ivysaur
# Type1:  Grass
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Ivysaur_(Pok%C3%A9mon)
# HP:  60
# ATK:  62
# DEF:  63
# SP_ATK:  80
# SP_DEF:  80
# SPD:  60
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #003
# Ndex:   #003
# Name:  Venusaur
# Type1:  Grass
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Venusaur_(Pok%C3%A9mon)
# HP:  80
# ATK:  82
# DEF:  83
# SP_ATK:  100
# SP_DEF:  100
# SPD:  80
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #004
# Ndex:   #004
# Name:  Charmander
# Type1:  Fire
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Charmander_(Pok%C3%A9mon)
# HP:  39
# ATK:  52
# DEF:  43
# SP_ATK:  60
# SP_DEF:  50
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #005
# Ndex:   #005
# Name:  Charmeleon
# Type1:  Fire
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Charmeleon_(Pok%C3%A9mon)
# HP:  58
# ATK:  64
# DEF:  58
# SP_ATK:  80
# SP_DEF:  65
# SPD:  80
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #006
# Ndex:   #006
# Name:  Charizard
# Type1:  Fire
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Charizard_(Pok%C3%A9mon)
# HP:  78
# ATK:  84
# DEF:  78
# SP_ATK:  109
# SP_DEF:  85
# SPD:  100
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Rock_4×', 'Water_2×', 'Electric_2×']
# Immue to : ['Ground_0×']
# Resisant to : ['Fighting_½×', 'Bug_¼×', 'Steel_½×', 'Fire_½×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #007
# Ndex:   #007
# Name:  Squirtle
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Squirtle_(Pok%C3%A9mon)
# HP:  44
# ATK:  48
# DEF:  65
# SP_ATK:  50
# SP_DEF:  64
# SPD:  43
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #008
# Ndex:   #008
# Name:  Wartortle
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Wartortle_(Pok%C3%A9mon)
# HP:  59
# ATK:  63
# DEF:  80
# SP_ATK:  65
# SP_DEF:  80
# SPD:  58
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #009
# Ndex:   #009
# Name:  Blastoise
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Blastoise_(Pok%C3%A9mon)
# HP:  79
# ATK:  83
# DEF:  100
# SP_ATK:  85
# SP_DEF:  105
# SPD:  78
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #010
# Ndex:   #010
# Name:  Caterpie
# Type1:  Bug
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Caterpie_(Pok%C3%A9mon)
# HP:  45
# ATK:  30
# DEF:  35
# SP_ATK:  20
# SP_DEF:  20
# SPD:  45
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Ground_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #011
# Ndex:   #011
# Name:  Metapod
# Type1:  Bug
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Metapod_(Pok%C3%A9mon)
# HP:  50
# ATK:  20
# DEF:  55
# SP_ATK:  25
# SP_DEF:  25
# SPD:  30
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Ground_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #012
# Ndex:   #012
# Name:  Butterfree
# Type1:  Bug
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Butterfree_(Pok%C3%A9mon)
# HP:  60
# ATK:  45
# DEF:  50
# SP_ATK:  80
# SP_DEF:  80
# SPD:  70
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_2×', 'Rock_4×', 'Fire_2×', 'Electric_2×', 'Ice_2×']
# Immue to : ['Ground_0×']
# Resisant to : ['Fighting_¼×', 'Bug_½×', 'Grass_¼×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #013
# Ndex:   #013
# Name:  Weedle
# Type1:  Bug
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Weedle_(Pok%C3%A9mon)
# HP:  40
# ATK:  35
# DEF:  30
# SP_ATK:  20
# SP_DEF:  20
# SPD:  50
# Damaged Normally by : ['Normal_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_½×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #014
# Ndex:   #014
# Name:  Kakuna
# Type1:  Bug
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Kakuna_(Pok%C3%A9mon)
# HP:  45
# ATK:  25
# DEF:  50
# SP_ATK:  25
# SP_DEF:  25
# SPD:  35
# Damaged Normally by : ['Normal_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_½×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #015
# Ndex:   #015
# Name:  Beedrill
# Type1:  Bug
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Beedrill_(Pok%C3%A9mon)
# HP:  65
# ATK:  80
# DEF:  40
# SP_ATK:  45
# SP_DEF:  80
# SPD:  75
# Damaged Normally by : ['Normal_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_½×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #016
# Ndex:   #016
# Name:  Pidgey
# Type1:  Normal
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Pidgey_(Pok%C3%A9mon)
# HP:  40
# ATK:  45
# DEF:  40
# SP_ATK:  35
# SP_DEF:  35
# SPD:  56
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Ice_2×']
# Immue to : ['Ground_0×', 'Ghost_0×']
# Resisant to : ['Bug_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #017
# Ndex:   #017
# Name:  Pidgeotto
# Type1:  Normal
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Pidgeotto_(Pok%C3%A9mon)
# HP:  63
# ATK:  60
# DEF:  55
# SP_ATK:  50
# SP_DEF:  50
# SPD:  71
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Ice_2×']
# Immue to : ['Ground_0×', 'Ghost_0×']
# Resisant to : ['Bug_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #018
# Ndex:   #018
# Name:  Pidgeot
# Type1:  Normal
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Pidgeot_(Pok%C3%A9mon)
# HP:  83
# ATK:  80
# DEF:  75
# SP_ATK:  70
# SP_DEF:  70
# SPD:  91
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Ice_2×']
# Immue to : ['Ground_0×', 'Ghost_0×']
# Resisant to : ['Bug_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #019
# Ndex:   #019
# Name:  Rattata
# Type1:  Normal
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Rattata_(Pok%C3%A9mon)
# HP:  30
# ATK:  56
# DEF:  35
# SP_ATK:  25
# SP_DEF:  35
# SPD:  72
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #019
# Name:  Rattata
# Type1:  Dark
# Type2:  Normal
# Link:  https://bulbapedia.bulbagarden.net//wiki/Rattata_(Pok%C3%A9mon)
# HP:  30
# ATK:  56
# DEF:  35
# SP_ATK:  25
# SP_DEF:  35
# SPD:  72
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #020
# Ndex:   #020
# Name:  Raticate
# Type1:  Normal
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Raticate_(Pok%C3%A9mon)
# HP:  55
# ATK:  81
# DEF:  60
# SP_ATK:  50
# SP_DEF:  70
# SPD:  97
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #020
# Name:  Raticate
# Type1:  Dark
# Type2:  Normal
# Link:  https://bulbapedia.bulbagarden.net//wiki/Raticate_(Pok%C3%A9mon)
# HP:  55
# ATK:  81
# DEF:  60
# SP_ATK:  50
# SP_DEF:  70
# SPD:  97
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #021
# Ndex:   #021
# Name:  Spearow
# Type1:  Normal
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Spearow_(Pok%C3%A9mon)
# HP:  40
# ATK:  60
# DEF:  30
# SP_ATK:  31
# SP_DEF:  31
# SPD:  70
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Ice_2×']
# Immue to : ['Ground_0×', 'Ghost_0×']
# Resisant to : ['Bug_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #022
# Ndex:   #022
# Name:  Fearow
# Type1:  Normal
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Fearow_(Pok%C3%A9mon)
# HP:  65
# ATK:  90
# DEF:  65
# SP_ATK:  61
# SP_DEF:  61
# SPD:  100
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Ice_2×']
# Immue to : ['Ground_0×', 'Ghost_0×']
# Resisant to : ['Bug_½×', 'Grass_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #023
# Ndex:   #023
# Name:  Ekans
# Type1:  Poison
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Ekans_(Pok%C3%A9mon)
# HP:  35
# ATK:  60
# DEF:  44
# SP_ATK:  40
# SP_DEF:  54
# SPD:  55
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Grass_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #024
# Ndex:   #024
# Name:  Arbok
# Type1:  Poison
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Arbok_(Pok%C3%A9mon)
# HP:  60
# ATK:  85
# DEF:  69
# SP_ATK:  65
# SP_DEF:  79
# SPD:  80
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Grass_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #025
# Ndex:   #025
# Name:  Pikachu
# Type1:  Electric
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Pikachu_(Pok%C3%A9mon)
# HP:  35
# ATK:  55
# DEF:  30
# SP_ATK:  50
# SP_DEF:  40
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Ground_2×']
# Immue to : ['None']
# Resisant to : ['Flying_½×', 'Steel_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #026
# Ndex:   #026
# Name:  Raichu
# Type1:  Electric
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Raichu_(Pok%C3%A9mon)
# HP:  60
# ATK:  90
# DEF:  55
# SP_ATK:  90
# SP_DEF:  80
# SPD:  100
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Ground_2×']
# Immue to : ['None']
# Resisant to : ['Flying_½×', 'Steel_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #026
# Name:  Raichu
# Type1:  Electric
# Type2:  Psychic
# Link:  https://bulbapedia.bulbagarden.net//wiki/Raichu_(Pok%C3%A9mon)
# HP:  60
# ATK:  90
# DEF:  55
# SP_ATK:  90
# SP_DEF:  80
# SPD:  100
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Ground_2×']
# Immue to : ['None']
# Resisant to : ['Flying_½×', 'Steel_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #027
# Ndex:   #027
# Name:  Sandshrew
# Type1:  Ground
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Sandshrew_(Pok%C3%A9mon)
# HP:  50
# ATK:  75
# DEF:  85
# SP_ATK:  20
# SP_DEF:  30
# SPD:  40
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #027
# Name:  Sandshrew
# Type1:  Ice
# Type2:  Steel
# Link:  https://bulbapedia.bulbagarden.net//wiki/Sandshrew_(Pok%C3%A9mon)
# HP:  50
# ATK:  75
# DEF:  85
# SP_ATK:  20
# SP_DEF:  30
# SPD:  40
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #028
# Ndex:   #028
# Name:  Sandslash
# Type1:  Ground
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Sandslash_(Pok%C3%A9mon)
# HP:  75
# ATK:  100
# DEF:  110
# SP_ATK:  45
# SP_DEF:  55
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #028
# Name:  Sandslash
# Type1:  Ice
# Type2:  Steel
# Link:  https://bulbapedia.bulbagarden.net//wiki/Sandslash_(Pok%C3%A9mon)
# HP:  75
# ATK:  100
# DEF:  110
# SP_ATK:  45
# SP_DEF:  55
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #029
# Ndex:   #029
# Name:  Nidoran♀
# Type1:  Poison
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Nidoran%E2%99%80_(Pok%C3%A9mon)
# HP:  55
# ATK:  47
# DEF:  52
# SP_ATK:  40
# SP_DEF:  40
# SPD:  41
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Grass_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #030
# Ndex:   #030
# Name:  Nidorina
# Type1:  Poison
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Nidorina_(Pok%C3%A9mon)
# HP:  70
# ATK:  62
# DEF:  67
# SP_ATK:  55
# SP_DEF:  55
# SPD:  56
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Grass_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #031
# Ndex:   #031
# Name:  Nidoqueen
# Type1:  Poison
# Type2:  Ground
# Link:  https://bulbapedia.bulbagarden.net//wiki/Nidoqueen_(Pok%C3%A9mon)
# HP:  90
# ATK:  82
# DEF:  87
# SP_ATK:  75
# SP_DEF:  85
# SPD:  76
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Grass_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Water_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Fighting_½×', 'Poison_¼×', 'Rock_½×', 'Bug_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #032
# Ndex:   #032
# Name:  Nidoran♂
# Type1:  Poison
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Nidoran%E2%99%82_(Pok%C3%A9mon)
# HP:  46
# ATK:  57
# DEF:  40
# SP_ATK:  40
# SP_DEF:  40
# SPD:  50
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Grass_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #033
# Ndex:   #033
# Name:  Nidorino
# Type1:  Poison
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Nidorino_(Pok%C3%A9mon)
# HP:  61
# ATK:  72
# DEF:  57
# SP_ATK:  55
# SP_DEF:  55
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Grass_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #034
# Ndex:   #034
# Name:  Nidoking
# Type1:  Poison
# Type2:  Ground
# Link:  https://bulbapedia.bulbagarden.net//wiki/Nidoking_(Pok%C3%A9mon)
# HP:  81
# ATK:  92
# DEF:  77
# SP_ATK:  85
# SP_DEF:  75
# SPD:  85
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Grass_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Water_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Fighting_½×', 'Poison_¼×', 'Rock_½×', 'Bug_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #035
# Ndex:   #035
# Name:  Clefairy
# Type1:  Fairy
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Clefairy_(Pok%C3%A9mon)
# HP:  70
# ATK:  45
# DEF:  48
# SP_ATK:  60
# SP_DEF:  65
# SPD:  35
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Dragon_0×']
# Resisant to : ['Fighting_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #036
# Ndex:   #036
# Name:  Clefable
# Type1:  Fairy
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Clefable_(Pok%C3%A9mon)
# HP:  95
# ATK:  70
# DEF:  73
# SP_ATK:  85
# SP_DEF:  90
# SPD:  60
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Dragon_0×']
# Resisant to : ['Fighting_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #037
# Ndex:   #037
# Name:  Vulpix
# Type1:  Fire
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Vulpix_(Pok%C3%A9mon)
# HP:  38
# ATK:  41
# DEF:  40
# SP_ATK:  50
# SP_DEF:  65
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #037
# Name:  Vulpix
# Type1:  Ice
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Vulpix_(Pok%C3%A9mon)
# HP:  38
# ATK:  41
# DEF:  40
# SP_ATK:  50
# SP_DEF:  65
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #038
# Ndex:   #038
# Name:  Ninetales
# Type1:  Fire
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Ninetales_(Pok%C3%A9mon)
# HP:  73
# ATK:  76
# DEF:  75
# SP_ATK:  81
# SP_DEF:  100
# SPD:  100
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #038
# Name:  Ninetales
# Type1:  Ice
# Type2:  Fairy
# Link:  https://bulbapedia.bulbagarden.net//wiki/Ninetales_(Pok%C3%A9mon)
# HP:  73
# ATK:  76
# DEF:  75
# SP_ATK:  81
# SP_DEF:  100
# SPD:  100
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #039
# Ndex:   #039
# Name:  Jigglypuff
# Type1:  Normal
# Type2:  Fairy
# Link:  https://bulbapedia.bulbagarden.net//wiki/Jigglypuff_(Pok%C3%A9mon)
# HP:  115
# ATK:  45
# DEF:  20
# SP_ATK:  45
# SP_DEF:  25
# SPD:  20
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Ghost_0×', 'Dragon_0×']
# Resisant to : ['Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #040
# Ndex:   #040
# Name:  Wigglytuff
# Type1:  Normal
# Type2:  Fairy
# Link:  https://bulbapedia.bulbagarden.net//wiki/Wigglytuff_(Pok%C3%A9mon)
# HP:  140
# ATK:  70
# DEF:  45
# SP_ATK:  75
# SP_DEF:  50
# SPD:  45
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Ghost_0×', 'Dragon_0×']
# Resisant to : ['Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #041
# Ndex:   #041
# Name:  Zubat
# Type1:  Poison
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Zubat_(Pok%C3%A9mon)
# HP:  40
# ATK:  45
# DEF:  35
# SP_ATK:  30
# SP_DEF:  40
# SPD:  55
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['Ground_0×']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_¼×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #042
# Ndex:   #042
# Name:  Golbat
# Type1:  Poison
# Type2:  Flying
# Link:  https://bulbapedia.bulbagarden.net//wiki/Golbat_(Pok%C3%A9mon)
# HP:  75
# ATK:  80
# DEF:  70
# SP_ATK:  65
# SP_DEF:  75
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Rock_2×', 'Electric_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['Ground_0×']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_¼×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #043
# Ndex:   #043
# Name:  Oddish
# Type1:  Grass
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Oddish_(Pok%C3%A9mon)
# HP:  45
# ATK:  50
# DEF:  55
# SP_ATK:  75
# SP_DEF:  65
# SPD:  30
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #044
# Ndex:   #044
# Name:  Gloom
# Type1:  Grass
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Gloom_(Pok%C3%A9mon)
# HP:  60
# ATK:  65
# DEF:  70
# SP_ATK:  85
# SP_DEF:  75
# SPD:  40
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #045
# Ndex:   #045
# Name:  Vileplume
# Type1:  Grass
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Vileplume_(Pok%C3%A9mon)
# HP:  75
# ATK:  80
# DEF:  85
# SP_ATK:  100
# SP_DEF:  90
# SPD:  50
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #046
# Ndex:   #046
# Name:  Paras
# Type1:  Bug
# Type2:  Grass
# Link:  https://bulbapedia.bulbagarden.net//wiki/Paras_(Pok%C3%A9mon)
# HP:  35
# ATK:  70
# DEF:  55
# SP_ATK:  45
# SP_DEF:  55
# SPD:  25
# Damaged Normally by : ['Normal_1×', 'Ghost_1×', 'Steel_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_4×', 'Poison_2×', 'Rock_2×', 'Bug_2×', 'Fire_4×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Ground_¼×', 'Water_½×', 'Grass_¼×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #047
# Ndex:   #047
# Name:  Parasect
# Type1:  Bug
# Type2:  Grass
# Link:  https://bulbapedia.bulbagarden.net//wiki/Parasect_(Pok%C3%A9mon)
# HP:  60
# ATK:  95
# DEF:  80
# SP_ATK:  60
# SP_DEF:  80
# SPD:  30
# Damaged Normally by : ['Normal_1×', 'Ghost_1×', 'Steel_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_4×', 'Poison_2×', 'Rock_2×', 'Bug_2×', 'Fire_4×', 'Ice_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Ground_¼×', 'Water_½×', 'Grass_¼×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #048
# Ndex:   #048
# Name:  Venonat
# Type1:  Bug
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Venonat_(Pok%C3%A9mon)
# HP:  60
# ATK:  55
# DEF:  50
# SP_ATK:  40
# SP_DEF:  55
# SPD:  45
# Damaged Normally by : ['Normal_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_½×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #049
# Ndex:   #049
# Name:  Venomoth
# Type1:  Bug
# Type2:  Poison
# Link:  https://bulbapedia.bulbagarden.net//wiki/Venomoth_(Pok%C3%A9mon)
# HP:  70
# ATK:  65
# DEF:  60
# SP_ATK:  90
# SP_DEF:  75
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Flying_2×', 'Rock_2×', 'Fire_2×', 'Psychic_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_¼×', 'Poison_½×', 'Bug_½×', 'Grass_¼×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #050
# Ndex:   #050
# Name:  Diglett
# Type1:  Ground
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Diglett_(Pok%C3%A9mon)
# HP:  10
# ATK:  55
# DEF:  25
# SP_ATK:  35
# SP_DEF:  45
# SPD:  95
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #050
# Name:  Diglett
# Type1:  Ground
# Type2:  Steel
# Link:  https://bulbapedia.bulbagarden.net//wiki/Diglett_(Pok%C3%A9mon)
# HP:  10
# ATK:  55
# DEF:  25
# SP_ATK:  35
# SP_DEF:  45
# SPD:  95
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #051
# Ndex:   #051
# Name:  Dugtrio
# Type1:  Ground
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Dugtrio_(Pok%C3%A9mon)
# HP:  35
# ATK:  80
# DEF:  50
# SP_ATK:  50
# SP_DEF:  70
# SPD:  120
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #051
# Name:  Dugtrio
# Type1:  Ground
# Type2:  Steel
# Link:  https://bulbapedia.bulbagarden.net//wiki/Dugtrio_(Pok%C3%A9mon)
# HP:  35
# ATK:  80
# DEF:  50
# SP_ATK:  50
# SP_DEF:  70
# SPD:  120
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Water_2×', 'Grass_2×', 'Ice_2×']
# Immue to : ['Electric_0×']
# Resisant to : ['Poison_½×', 'Rock_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #052
# Ndex:   #052
# Name:  Meowth
# Type1:  Normal
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Meowth_(Pok%C3%A9mon)
# HP:  40
# ATK:  45
# DEF:  35
# SP_ATK:  40
# SP_DEF:  40
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #052
# Name:  Meowth
# Type1:  Dark
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Meowth_(Pok%C3%A9mon)
# HP:  40
# ATK:  45
# DEF:  35
# SP_ATK:  40
# SP_DEF:  40
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #052
# Name:  Meowth
# Type1:  Steel
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Meowth_(Pok%C3%A9mon)
# HP:  40
# ATK:  45
# DEF:  35
# SP_ATK:  40
# SP_DEF:  40
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #053
# Ndex:   #053
# Name:  Persian
# Type1:  Normal
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Persian_(Pok%C3%A9mon)
# HP:  65
# ATK:  70
# DEF:  60
# SP_ATK:  65
# SP_DEF:  65
# SPD:  115
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:
# Ndex:   #053
# Name:  Persian
# Type1:  Dark
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Persian_(Pok%C3%A9mon)
# HP:  65
# ATK:  70
# DEF:  60
# SP_ATK:  65
# SP_DEF:  65
# SPD:  115
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['None']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #054
# Ndex:   #054
# Name:  Psyduck
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Psyduck_(Pok%C3%A9mon)
# HP:  50
# ATK:  52
# DEF:  48
# SP_ATK:  65
# SP_DEF:  50
# SPD:  55
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #055
# Ndex:   #055
# Name:  Golduck
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Golduck_(Pok%C3%A9mon)
# HP:  80
# ATK:  82
# DEF:  78
# SP_ATK:  95
# SP_DEF:  80
# SPD:  85
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #056
# Ndex:   #056
# Name:  Mankey
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Mankey_(Pok%C3%A9mon)
# HP:  40
# ATK:  80
# DEF:  35
# SP_ATK:  35
# SP_DEF:  45
# SPD:  70
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #057
# Ndex:   #057
# Name:  Primeape
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Primeape_(Pok%C3%A9mon)
# HP:  65
# ATK:  105
# DEF:  60
# SP_ATK:  60
# SP_DEF:  70
# SPD:  95
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #058
# Ndex:   #058
# Name:  Growlithe
# Type1:  Fire
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Growlithe_(Pok%C3%A9mon)
# HP:  55
# ATK:  70
# DEF:  45
# SP_ATK:  70
# SP_DEF:  50
# SPD:  60
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #059
# Ndex:   #059
# Name:  Arcanine
# Type1:  Fire
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Arcanine_(Pok%C3%A9mon)
# HP:  90
# ATK:  110
# DEF:  80
# SP_ATK:  100
# SP_DEF:  80
# SPD:  95
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Rock_2×', 'Water_2×']
# Immue to : ['None']
# Resisant to : ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', 'Ice_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #060
# Ndex:   #060
# Name:  Poliwag
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Poliwag_(Pok%C3%A9mon)
# HP:  40
# ATK:  50
# DEF:  40
# SP_ATK:  40
# SP_DEF:  40
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #061
# Ndex:   #061
# Name:  Poliwhirl
# Type1:  Water
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Poliwhirl_(Pok%C3%A9mon)
# HP:  65
# ATK:  65
# DEF:  65
# SP_ATK:  50
# SP_DEF:  50
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #062
# Ndex:   #062
# Name:  Poliwrath
# Type1:  Water
# Type2:  Fighting
# Link:  https://bulbapedia.bulbagarden.net//wiki/Poliwrath_(Pok%C3%A9mon)
# HP:  90
# ATK:  85
# DEF:  95
# SP_ATK:  70
# SP_DEF:  90
# SPD:  70
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Grass_2×', 'Electric_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Steel_½×', 'Fire_½×', 'Water_½×', 'Ice_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #063
# Ndex:   #063
# Name:  Abra
# Type1:  Psychic
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Abra_(Pok%C3%A9mon)
# HP:  25
# ATK:  20
# DEF:  15
# SP_ATK:  105
# SP_DEF:  55
# SPD:  90
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Fairy_1×']
# Weak to : ['Bug_2×', 'Ghost_2×', 'Dark_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Psychic_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #064
# Ndex:   #064
# Name:  Kadabra
# Type1:  Psychic
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Kadabra_(Pok%C3%A9mon)
# HP:  40
# ATK:  35
# DEF:  30
# SP_ATK:  120
# SP_DEF:  70
# SPD:  105
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Fairy_1×']
# Weak to : ['Bug_2×', 'Ghost_2×', 'Dark_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Psychic_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #065
# Ndex:   #065
# Name:  Alakazam
# Type1:  Psychic
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Alakazam_(Pok%C3%A9mon)
# HP:  55
# ATK:  50
# DEF:  45
# SP_ATK:  135
# SP_DEF:  85
# SPD:  120
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Fairy_1×']
# Weak to : ['Bug_2×', 'Ghost_2×', 'Dark_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Psychic_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #066
# Ndex:   #066
# Name:  Machop
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Machop_(Pok%C3%A9mon)
# HP:  70
# ATK:  80
# DEF:  50
# SP_ATK:  35
# SP_DEF:  35
# SPD:  35
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #067
# Ndex:   #067
# Name:  Machoke
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Machoke_(Pok%C3%A9mon)
# HP:  80
# ATK:  100
# DEF:  70
# SP_ATK:  50
# SP_DEF:  60
# SPD:  45
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #068
# Ndex:   #068
# Name:  Machamp
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Machamp_(Pok%C3%A9mon)
# HP:  90
# ATK:  130
# DEF:  80
# SP_ATK:  65
# SP_DEF:  85
# SPD:  55
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# ...
# Weak to : ['Ghost_2×', 'Water_2×', 'Grass_2×', 'Ice_2×', 'Dark_2×']
# Immue to : ['Normal_0×', 'Fighting_0×', 'Electric_0×']
# Resisant to : ['Poison_¼×', 'Rock_½×', 'Bug_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #185
# Ndex:   #868
# Name:  Milcery
# Type1:  Fairy
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Milcery_(Pok%C3%A9mon)
# HP:  45
# ATK:  40
# DEF:  40
# SP_ATK:  50
# SP_DEF:  61
# SPD:  34
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Dragon_0×']
# Resisant to : ['Fighting_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #186
# Ndex:   #869
# Name:  Alcremie
# Type1:  Fairy
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Alcremie_(Pok%C3%A9mon)
# HP:  65
# ATK:  60
# DEF:  75
# SP_ATK:  110
# SP_DEF:  121
# SPD:  64
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Dragon_0×']
# Resisant to : ['Fighting_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #345
# Ndex:   #870
# Name:  Falinks
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Falinks_(Pok%C3%A9mon)
# HP:  65
# ATK:  100
# DEF:  100
# SP_ATK:  70
# SP_DEF:  60
# SPD:  75
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #353
# Ndex:   #871
# Name:  Pincurchin
# Type1:  Electric
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Pincurchin_(Pok%C3%A9mon)
# HP:  48
# ATK:  101
# DEF:  95
# SP_ATK:  91
# SP_DEF:  85
# SPD:  15
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Ground_2×']
# Immue to : ['None']
# Resisant to : ['Flying_½×', 'Steel_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #349
# Ndex:   #872
# Name:  Snom
# Type1:  Ice
# Type2:  Bug
# Link:  https://bulbapedia.bulbagarden.net//wiki/Snom_(Pok%C3%A9mon)
# HP:  30
# ATK:  25
# DEF:  35
# SP_ATK:  45
# SP_DEF:  30
# SPD:  20
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Bug_1×', 'Ghost_1×', 'Water_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_2×', 'Rock_4×', 'Steel_2×', 'Fire_4×']
# Immue to : ['None']
# Resisant to : ['Ground_½×', 'Grass_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #350
# Ndex:   #873
# Name:  Frosmoth
# Type1:  Ice
# Type2:  Bug
# Link:  https://bulbapedia.bulbagarden.net//wiki/Frosmoth_(Pok%C3%A9mon)
# HP:  70
# ATK:  65
# DEF:  60
# SP_ATK:  125
# SP_DEF:  90
# SPD:  65
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Bug_1×', 'Ghost_1×', 'Water_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Flying_2×', 'Rock_4×', 'Steel_2×', 'Fire_4×']
# Immue to : ['None']
# Resisant to : ['Ground_½×', 'Grass_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #369
# Ndex:   #874
# Name:  Stonjourner
# Type1:  Rock
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Stonjourner_(Pok%C3%A9mon)
# HP:  100
# ATK:  125
# DEF:  135
# SP_ATK:  20
# SP_DEF:  20
# SPD:  70
# Damaged Normally by : ['Rock_1×', 'Bug_1×', 'Ghost_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×', 'Ground_2×', 'Steel_2×', 'Water_2×', 'Grass_2×']
# Immue to : ['None']
# Resisant to : ['Normal_½×', 'Flying_½×', 'Poison_½×', 'Fire_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #370
# Ndex:   #875
# Name:  Eiscue
# Type1:  Ice
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Eiscue_(Pok%C3%A9mon)
# HP:  75
# ATK:  80
# DEF:  110
# SP_ATK:  65
# SP_DEF:  90
# SPD:  50
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×', 'Rock_2×', 'Steel_2×', 'Fire_2×']
# Immue to : ['None']
# Resisant to : ['Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #337
# Ndex:   #876
# Name:  Indeedee
# Type1:  Psychic
# Type2:  Normal
# Link:  https://bulbapedia.bulbagarden.net//wiki/Indeedee_(Pok%C3%A9mon)
# HP:  60
# ATK:  65
# DEF:  55
# SP_ATK:  105
# SP_DEF:  95
# SPD:  95
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×', 'Fairy_1×']
# Weak to : ['Bug_2×', 'Dark_2×']
# Immue to : ['Ghost_0×']
# Resisant to : ['Psychic_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #344
# Ndex:   #877
# Name:  Morpeko
# Type1:  Electric
# Type2:  Dark
# Link:  https://bulbapedia.bulbagarden.net//wiki/Morpeko_(Pok%C3%A9mon)
# HP:  58
# ATK:  95
# DEF:  58
# SP_ATK:  70
# SP_DEF:  58
# SPD:  97
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Rock_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Fighting_2×', 'Ground_2×', 'Bug_2×', 'Fairy_2×']
# Immue to : ['Psychic_0×']
# Resisant to : ['Flying_½×', 'Ghost_½×', 'Steel_½×', 'Electric_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #302
# Ndex:   #878
# Name:  Cufant
# Type1:  Steel
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Cufant_(Pok%C3%A9mon)
# HP:  72
# ATK:  80
# DEF:  49
# SP_ATK:  40
# SP_DEF:  49
# SPD:  40
# Damaged Normally by : ['Ghost_1×', 'Water_1×', 'Electric_1×', 'Dark_1×']
# Weak to : ['Fighting_2×', 'Ground_2×', 'Fire_2×']
# Immue to : ['Poison_0×']
# Resisant to : ['Normal_½×', 'Flying_½×', 'Rock_½×', 'Bug_½×', 'Steel_½×', 'Grass_½×', 'Psychic_½×', 'Ice_½×', 'Dragon_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #303
# Ndex:   #879
# Name:  Copperajah
# Type1:  Steel
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Copperajah_(Pok%C3%A9mon)
# HP:  122
# ATK:  130
# DEF:  69
# SP_ATK:  80
# SP_DEF:  69
# SPD:  30
# Damaged Normally by : ['Ghost_1×', 'Water_1×', 'Electric_1×', 'Dark_1×']
# Weak to : ['Fighting_2×', 'Ground_2×', 'Fire_2×']
# Immue to : ['Poison_0×']
# Resisant to : ['Normal_½×', 'Flying_½×', 'Rock_½×', 'Bug_½×', 'Steel_½×', 'Grass_½×', 'Psychic_½×', 'Ice_½×', 'Dragon_½×', 'Fairy_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #374
# Ndex:   #880
# Name:  Dracozolt
# Type1:  Electric
# Type2:  Dragon
# Link:  https://bulbapedia.bulbagarden.net//wiki/Dracozolt_(Pok%C3%A9mon)
# HP:  90
# ATK:  100
# DEF:  90
# SP_ATK:  80
# SP_DEF:  70
# SPD:  75
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Psychic_1×', 'Dark_1×']
# Weak to : ['Ground_2×', 'Ice_2×', 'Dragon_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Flying_½×', 'Steel_½×', 'Fire_½×', 'Water_½×', 'Grass_½×', 'Electric_¼×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #375
# Ndex:   #881
# Name:  Arctozolt
# Type1:  Electric
# Type2:  Ice
# Link:  https://bulbapedia.bulbagarden.net//wiki/Arctozolt_(Pok%C3%A9mon)
# HP:  90
# ATK:  100
# DEF:  90
# SP_ATK:  90
# SP_DEF:  80
# SPD:  55
# Damaged Normally by : ['Normal_1×', 'Poison_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Water_1×', 'Grass_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×', 'Ground_2×', 'Rock_2×', 'Fire_2×']
# Immue to : ['None']
# Resisant to : ['Flying_½×', 'Electric_½×', 'Ice_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #376
# Ndex:   #882
# Name:  Dracovish
# Type1:  Water
# Type2:  Dragon
# Link:  https://bulbapedia.bulbagarden.net//wiki/Dracovish_(Pok%C3%A9mon)
# HP:  90
# ATK:  90
# DEF:  100
# SP_ATK:  70
# SP_DEF:  80
# SPD:  75
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Rock_1×', 'Bug_1×', 'Ghost_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Dark_1×']
# Weak to : ['Dragon_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Steel_½×', 'Fire_¼×', 'Water_¼×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #377
# Ndex:   #883
# Name:  Arctovish
# Type1:  Water
# Type2:  Ice
# Link:  https://bulbapedia.bulbagarden.net//wiki/Arctovish_(Pok%C3%A9mon)
# HP:  90
# ATK:  90
# DEF:  100
# SP_ATK:  80
# SP_DEF:  90
# SPD:  55
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Poison_1×', 'Ground_1×', 'Bug_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Psychic_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×', 'Rock_2×', 'Grass_2×', 'Electric_2×']
# Immue to : ['None']
# Resisant to : ['Water_½×', 'Ice_¼×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #371
# Ndex:   #884
# Name:  Duraludon
# Type1:  Steel
# Type2:  Dragon
# Link:  https://bulbapedia.bulbagarden.net//wiki/Duraludon_(Pok%C3%A9mon)
# HP:  70
# ATK:  95
# DEF:  115
# SP_ATK:  120
# SP_DEF:  50
# SPD:  85
# Damaged Normally by : ['Ghost_1×', 'Fire_1×', 'Ice_1×', 'Dragon_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Fighting_2×', 'Ground_2×']
# Immue to : ['Poison_0×']
# Resisant to : ['Normal_½×', 'Flying_½×', 'Rock_½×', 'Bug_½×', 'Steel_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×', 'Psychic_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #395
# Ndex:   #885
# Name:  Dreepy
# Type1:  Dragon
# Type2:  Ghost
# Link:  https://bulbapedia.bulbagarden.net//wiki/Dreepy_(Pok%C3%A9mon)
# HP:  28
# ATK:  60
# DEF:  30
# SP_ATK:  40
# SP_DEF:  30
# SPD:  82
# Damaged Normally by : ['Flying_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Psychic_1×']
# Weak to : ['Ghost_2×', 'Ice_2×', 'Dragon_2×', 'Dark_2×', 'Fairy_2×']
# Immue to : ['Normal_0×', 'Fighting_0×']
# Resisant to : ['Poison_½×', 'Bug_½×', 'Fire_½×', 'Water_½×', 'Grass_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #396
# Ndex:   #886
# Name:  Drakloak
# Type1:  Dragon
# Type2:  Ghost
# Link:  https://bulbapedia.bulbagarden.net//wiki/Drakloak_(Pok%C3%A9mon)
# HP:  68
# ATK:  80
# DEF:  50
# SP_ATK:  60
# SP_DEF:  50
# SPD:  102
# Damaged Normally by : ['Flying_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Psychic_1×']
# Weak to : ['Ghost_2×', 'Ice_2×', 'Dragon_2×', 'Dark_2×', 'Fairy_2×']
# Immue to : ['Normal_0×', 'Fighting_0×']
# Resisant to : ['Poison_½×', 'Bug_½×', 'Fire_½×', 'Water_½×', 'Grass_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #397
# Ndex:   #887
# Name:  Dragapult
# Type1:  Dragon
# Type2:  Ghost
# Link:  https://bulbapedia.bulbagarden.net//wiki/Dragapult_(Pok%C3%A9mon)
# HP:  88
# ATK:  120
# DEF:  75
# SP_ATK:  100
# SP_DEF:  75
# SPD:  142
# Damaged Normally by : ['Flying_1×', 'Ground_1×', 'Rock_1×', 'Steel_1×', 'Psychic_1×']
# Weak to : ['Ghost_2×', 'Ice_2×', 'Dragon_2×', 'Dark_2×', 'Fairy_2×']
# Immue to : ['Normal_0×', 'Fighting_0×']
# Resisant to : ['Poison_½×', 'Bug_½×', 'Fire_½×', 'Water_½×', 'Grass_½×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #398
# Ndex:   #888
# Name:  Zacian
# Type1:  Fairy
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Zacian_(Pok%C3%A9mon)
# HP:  92
# ATK:  130
# DEF:  115
# SP_ATK:  80
# SP_DEF:  115
# SPD:  138
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Dragon_0×']
# Resisant to : ['Fighting_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #398
# Ndex:   #888
# Name:  Zacian
# Type1:  Fairy
# Type2:  Steel
# Link:  https://bulbapedia.bulbagarden.net//wiki/Zacian_(Pok%C3%A9mon)
# HP:  92
# ATK:  130
# DEF:  115
# SP_ATK:  80
# SP_DEF:  115
# SPD:  138
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Ground_1×', 'Rock_1×', 'Ghost_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Psychic_1×', 'Ice_1×', 'Fairy_1×']
# Weak to : ['Poison_2×', 'Steel_2×']
# Immue to : ['Dragon_0×']
# Resisant to : ['Fighting_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #399
# Ndex:   #889
# Name:  Zamazenta
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Zamazenta_(Pok%C3%A9mon)
# HP:  92
# ATK:  130
# DEF:  115
# SP_ATK:  80
# SP_DEF:  115
# SPD:  138
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #399
# Ndex:   #889
# Name:  Zamazenta
# Type1:  Fighting
# Type2:  Steel
# Link:  https://bulbapedia.bulbagarden.net//wiki/Zamazenta_(Pok%C3%A9mon)
# HP:  92
# ATK:  130
# DEF:  115
# SP_ATK:  80
# SP_DEF:  115
# SPD:  138
# Damaged Normally by : ['Normal_1×', 'Fighting_1×', 'Poison_1×', 'Ground_1×', 'Ghost_1×', 'Steel_1×', 'Fire_1×', 'Water_1×', 'Grass_1×', 'Electric_1×', 'Ice_1×', 'Dragon_1×']
# Weak to : ['Flying_2×', 'Psychic_2×', 'Fairy_2×']
# Immue to : ['None']
# Resisant to : ['Rock_½×', 'Bug_½×', 'Dark_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #400
# Ndex:   #890
# Name:  Eternatus
# Type1:  Poison
# Type2:  Dragon
# Link:  https://bulbapedia.bulbagarden.net//wiki/Eternatus_(Pok%C3%A9mon)
# HP:  140
# ATK:  85
# DEF:  95
# SP_ATK:  145
# SP_DEF:  95
# SPD:  130
# Damaged Normally by : ['Normal_1×', 'Flying_1×', 'Rock_1×', 'Ghost_1×', 'Steel_1×', 'Dark_1×', 'Fairy_1×']
# Weak to : ['Ground_2×', 'Psychic_2×', 'Ice_2×', 'Dragon_2×']
# Immue to : ['None']
# Resisant to : ['Fighting_½×', 'Poison_½×', 'Bug_½×', 'Fire_½×', 'Water_½×', 'Grass_¼×', 'Electric_½×']
# Writting...
# Done!!!
# ==============================================================================
#
# Loading...
# Kdex:   #???
# Ndex:   #???
# Name:  Kubfu
# Type1:  Fighting
# Type2:  Null
# Link:  https://bulbapedia.bulbagarden.net//wiki/Kubfu_(Pok%C3%A9mon)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-e28386545c8c> in <module>
#      47
#      48     #hp
# ---> 49     hp=soup_pkm.find('tr',{'style':"background: #FF5959; text-align:center"}).find('div',{'style':'float:right'}).text
#      50     print("HP: ",hp)
#      51     pokemon_data.append(hp)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
f.close()
