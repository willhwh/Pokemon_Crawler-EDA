# %%
#library

# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import csv
import time
import random
import pandas as pd

# %%
#get data

# %%
url='https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number'
r=requests.get(url)
r.encoding = 'utf-8'

# %%
#compile data
soup=BeautifulSoup(r.text,"html5lib")

# %%
#create folder
folder = os.path.exists('Pokemon_data')
if not folder:
#如果不存在，則建立新目錄
    os.makedirs('Pokemon_data')

# %%
#create file
f = open("Pokemon_data/" + 'pokemon_data.csv', "a+"
                     #open for writing, appending to the end of the file if it exists
                     #open for updating (reading and writing)
                     #https://docs.python.org/3/library/functions.html
                     , encoding='utf-8')

# %%
#open file and create column names
with open('pokemon_data.csv', 'a', newline='') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerow(['Kdex','Ndex','Name','Type1','Type2','Link',
               'HP','ATK','DEF','SP_ATK','SP_DEF','SPD',
               'Damaged Normally by','Weak to','Immue to','Resisant to'])

# %%
#arrange data
counter=0 #counter
for i in soup.find('div',{'id':'mw-content-text'}).find_all('tr',{"style":"background:#FFF"}):
    counter=counter+1 #counter
    pokemon_data=[]    
    #generate_number
    generate_number=i.find_all('td')[0].text.replace('\n',"")
    #print('Kdex: ',generate_number)
    pokemon_data.append(generate_number)
    
    
    #national_number
    national_number=i.find_all('td')[1].text.replace('\n',"")
    #print('Ndex: ',national_number)
    pokemon_data.append(national_number)
    
    
    #name
    name=i.find('a')['title']
    #print('Name: ',name)
    pokemon_data.append(name)
    print('Loading...',name,"'s Data")
    
    
    #type1
    type1=i.find_all('span')[0].text
    #print('Type1: ',type1)
    pokemon_data.append(type1)
    
    
    #type2 if exist
    if len(i.find_all('span'))==2:
        type2=i.find_all('span')[1].text
        #print('Type2: ',type2)
        pokemon_data.append(type2)
    else:
        type2='Null'
        #print('Type2: ',type2)
        pokemon_data.append(type2)
        
        
    #link to specific attr
    link='https://bulbapedia.bulbagarden.net/'+i.find_all('a',
                                                          href=re.compile("^(/wiki/)((?!;)\S)*$"))[1]['href']
    #print('Link: ',link)
    pokemon_data.append(link)    
    
    
    
    #set timer 
    sleep=random.randint(0,3)
    time.sleep(sleep)
    #print('sleep time: ',sleep)
    
    
    #get specific attr for a pokemon
    url_pkm=link
    r_pkm=requests.get(url_pkm)
    r_pkm.encoding = 'utf-8'
    soup_pkm=BeautifulSoup(r_pkm.text,"html5lib")
    try:
        #hp
        hp=soup_pkm.find('tr',{'style':"background: #FF5959; text-align:center"}).find('div',{'style':'float:right'}).text
        #print("HP: ",hp) 
        pokemon_data.append(hp)
        #atk
        atk=soup_pkm.find('tr',{'style':"background: #F5AC78; text-align:center"}).find('div',{'style':'float:right'}).text
        #print("ATK: ",atk) 
        pokemon_data.append(atk)
        #def
        defense=soup_pkm.find('tr',{'style':"background: #FAE078; text-align:center"}).find('div',{'style':'float:right'}).text
        #print("DEF: ",defense)
        pokemon_data.append(defense)
        #sp_atk
        sp_atk=soup_pkm.find('tr',{'style':"background: #9DB7F5; text-align:center"}).find('div',{'style':'float:right'}).text
        #print("SP_ATK: ",sp_atk)  
        pokemon_data.append(sp_atk)
        #sp_def
        sp_defense=soup_pkm.find('tr',{'style':"background: #A7DB8D; text-align:center"}).find('div',{'style':'float:right'}).text
        #print("SP_DEF: ",sp_defense)
        pokemon_data.append(sp_defense)
        #spd
        spd=soup_pkm.find('tr',{'style':"background: #FA92B2; text-align:center"}).find('div',{'style':'float:right'}).text
        #print("SPD: ",spd)
        pokemon_data.append(spd)

        
        #type_effectiveness
        type_effectiveness=soup_pkm.find('table',{'class':'roundy','width':'100%','align':'center'}) 
        #get four dimentions 
        normal=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[1]
        weak=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[2]
        immue=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[3]
        resisant=type_effectiveness.find_all('table',{'class':'roundy','width':'100%','align':'center'})[4]
        #create list for each dimention
        normal_lst=[]
        weak_lst=[]
        immue_lst=[]
        resisant_lst=[]
    
    
        #get data into each list and write
        #Damaged Normally by
        for j in normal.find_all('span',{'style':'display:inline-block;'}):
            normal_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
        #print('Damaged Normally by :',normal_lst)
        pokemon_data.append(str(normal_lst))
    
    
        #Weak to
        for j in weak.find_all('span',{'style':'display:inline-block;'}):
            weak_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
        #print('Weak to :',weak_lst)
        pokemon_data.append(str(weak_lst))
    
    
        #Immue to
        for j in immue.find_all('span',{'style':'display:inline-block;'}):
            immue_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
        #print('Immue to :',immue_lst)
        pokemon_data.append(str(immue_lst))
    
    
        #Resisant to
        for j in resisant.find_all('span',{'style':'display:inline-block;'}):
            resisant_lst.append(j.text.replace('\n','').strip().replace(' ','_'))
        #print('Resisant to :',resisant_lst)
        pokemon_data.append(str(resisant_lst))
    
    
    #writting data    
        with open('pokemon_data.csv', 'a', newline='') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerow(pokemon_data)
    
        print('Writting...',name,"'s Info")
        print('Done!!!')
        print('==============================================================================\n')

    
    #counter for testing     
        #if counter ==1:
            #break
        #else:
        #    continue
    except:
        continue
# Out:
# Loading... Bulbasaur 's Data
# Writting... Bulbasaur 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ivysaur 's Data
# Writting... Ivysaur 's Info
# Done!!!
# ==============================================================================
#
# Loading... Venusaur 's Data
# Writting... Venusaur 's Info
# Done!!!
# ==============================================================================
#
# Loading... Charmander 's Data
# Writting... Charmander 's Info
# Done!!!
# ==============================================================================
#
# Loading... Charmeleon 's Data
# Writting... Charmeleon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Charizard 's Data
# Writting... Charizard 's Info
# Done!!!
# ==============================================================================
#
# Loading... Squirtle 's Data
# Writting... Squirtle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wartortle 's Data
# Writting... Wartortle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Blastoise 's Data
# Writting... Blastoise 's Info
# Done!!!
# ==============================================================================
#
# Loading... Caterpie 's Data
# Writting... Caterpie 's Info
# Done!!!
# ==============================================================================
#
# Loading... Metapod 's Data
# Writting... Metapod 's Info
# Done!!!
# ==============================================================================
#
# Loading... Butterfree 's Data
# Writting... Butterfree 's Info
# Done!!!
# ==============================================================================
#
# Loading... Weedle 's Data
# Writting... Weedle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kakuna 's Data
# Writting... Kakuna 's Info
# Done!!!
# ==============================================================================
#
# Loading... Beedrill 's Data
# Writting... Beedrill 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pidgey 's Data
# Writting... Pidgey 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pidgeotto 's Data
# Writting... Pidgeotto 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pidgeot 's Data
# Writting... Pidgeot 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rattata 's Data
# Writting... Rattata 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rattata 's Data
# Writting... Rattata 's Info
# Done!!!
# ==============================================================================
#
# Loading... Raticate 's Data
# Writting... Raticate 's Info
# Done!!!
# ==============================================================================
#
# Loading... Raticate 's Data
# Writting... Raticate 's Info
# Done!!!
# ==============================================================================
#
# Loading... Spearow 's Data
# Writting... Spearow 's Info
# Done!!!
# ==============================================================================
#
# Loading... Fearow 's Data
# Writting... Fearow 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ekans 's Data
# Writting... Ekans 's Info
# Done!!!
# ==============================================================================
#
# Loading... Arbok 's Data
# Writting... Arbok 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pikachu 's Data
# Writting... Pikachu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Raichu 's Data
# Writting... Raichu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Raichu 's Data
# Writting... Raichu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sandshrew 's Data
# Writting... Sandshrew 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sandshrew 's Data
# Writting... Sandshrew 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sandslash 's Data
# Writting... Sandslash 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sandslash 's Data
# Writting... Sandslash 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nidoran♀ 's Data
# Writting... Nidoran♀ 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nidorina 's Data
# Writting... Nidorina 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nidoqueen 's Data
# Writting... Nidoqueen 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nidoran♂ 's Data
# Writting... Nidoran♂ 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nidorino 's Data
# Writting... Nidorino 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nidoking 's Data
# Writting... Nidoking 's Info
# Done!!!
# ==============================================================================
#
# Loading... Clefairy 's Data
# Writting... Clefairy 's Info
# Done!!!
# ==============================================================================
#
# Loading... Clefable 's Data
# Writting... Clefable 's Info
# Done!!!
# ==============================================================================
#
# Loading... Vulpix 's Data
# Writting... Vulpix 's Info
# Done!!!
# ==============================================================================
#
# Loading... Vulpix 's Data
# Writting... Vulpix 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ninetales 's Data
# Writting... Ninetales 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ninetales 's Data
# Writting... Ninetales 's Info
# Done!!!
# ==============================================================================
#
# Loading... Jigglypuff 's Data
# Writting... Jigglypuff 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wigglytuff 's Data
# Writting... Wigglytuff 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zubat 's Data
# Writting... Zubat 's Info
# Done!!!
# ==============================================================================
#
# Loading... Golbat 's Data
# Writting... Golbat 's Info
# Done!!!
# ==============================================================================
#
# Loading... Oddish 's Data
# Writting... Oddish 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gloom 's Data
# Writting... Gloom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Vileplume 's Data
# Writting... Vileplume 's Info
# Done!!!
# ==============================================================================
#
# Loading... Paras 's Data
# Writting... Paras 's Info
# Done!!!
# ==============================================================================
#
# Loading... Parasect 's Data
# Writting... Parasect 's Info
# Done!!!
# ==============================================================================
#
# Loading... Venonat 's Data
# Writting... Venonat 's Info
# Done!!!
# ==============================================================================
#
# Loading... Venomoth 's Data
# Writting... Venomoth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Diglett 's Data
# Writting... Diglett 's Info
# Done!!!
# ==============================================================================
#
# Loading... Diglett 's Data
# Writting... Diglett 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dugtrio 's Data
# Writting... Dugtrio 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dugtrio 's Data
# Writting... Dugtrio 's Info
# Done!!!
# ==============================================================================
#
# Loading... Meowth 's Data
# Writting... Meowth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Meowth 's Data
# Writting... Meowth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Meowth 's Data
# Writting... Meowth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Persian 's Data
# Writting... Persian 's Info
# Done!!!
# ==============================================================================
#
# Loading... Persian 's Data
# Writting... Persian 's Info
# Done!!!
# ==============================================================================
#
# Loading... Psyduck 's Data
# Writting... Psyduck 's Info
# Done!!!
# ==============================================================================
#
# Loading... Golduck 's Data
# Writting... Golduck 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mankey 's Data
# Writting... Mankey 's Info
# Done!!!
# ==============================================================================
#
# Loading... Primeape 's Data
# Writting... Primeape 's Info
# Done!!!
# ==============================================================================
#
# Loading... Growlithe 's Data
# Writting... Growlithe 's Info
# Done!!!
# ==============================================================================
#
# Loading... Arcanine 's Data
# Writting... Arcanine 's Info
# Done!!!
# ==============================================================================
#
# Loading... Poliwag 's Data
# Writting... Poliwag 's Info
# Done!!!
# ==============================================================================
#
# Loading... Poliwhirl 's Data
# Writting... Poliwhirl 's Info
# Done!!!
# ==============================================================================
#
# Loading... Poliwrath 's Data
# Writting... Poliwrath 's Info
# Done!!!
# ==============================================================================
#
# Loading... Abra 's Data
# Writting... Abra 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kadabra 's Data
# Writting... Kadabra 's Info
# Done!!!
# ==============================================================================
#
# Loading... Alakazam 's Data
# Writting... Alakazam 's Info
# Done!!!
# ==============================================================================
#
# Loading... Machop 's Data
# Writting... Machop 's Info
# Done!!!
# ==============================================================================
#
# Loading... Machoke 's Data
# Writting... Machoke 's Info
# Done!!!
# ==============================================================================
#
# Loading... Machamp 's Data
# Writting... Machamp 's Info
# Done!!!
# ==============================================================================
#
# Loading... Bellsprout 's Data
# Writting... Bellsprout 's Info
# Done!!!
# ==============================================================================
#
# Loading... Weepinbell 's Data
# Writting... Weepinbell 's Info
# Done!!!
# ==============================================================================
#
# Loading... Victreebel 's Data
# Writting... Victreebel 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tentacool 's Data
# Writting... Tentacool 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tentacruel 's Data
# Writting... Tentacruel 's Info
# Done!!!
# ==============================================================================
#
# Loading... Geodude 's Data
# Writting... Geodude 's Info
# Done!!!
# ==============================================================================
#
# Loading... Geodude 's Data
# Writting... Geodude 's Info
# Done!!!
# ==============================================================================
#
# Loading... Graveler 's Data
# Writting... Graveler 's Info
# Done!!!
# ==============================================================================
#
# Loading... Graveler 's Data
# Writting... Graveler 's Info
# Done!!!
# ==============================================================================
#
# Loading... Golem 's Data
# Writting... Golem 's Info
# Done!!!
# ==============================================================================
#
# Loading... Golem 's Data
# Writting... Golem 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ponyta 's Data
# Writting... Ponyta 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ponyta 's Data
# Writting... Ponyta 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rapidash 's Data
# Writting... Rapidash 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rapidash 's Data
# Writting... Rapidash 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slowpoke 's Data
# Writting... Slowpoke 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slowpoke 's Data
# Writting... Slowpoke 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slowbro 's Data
# Writting... Slowbro 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slowbro 's Data
# Writting... Slowbro 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magnemite 's Data
# Writting... Magnemite 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magneton 's Data
# Writting... Magneton 's Info
# Done!!!
# ==============================================================================
#
# Loading... Farfetch'd 's Data
# Writting... Farfetch'd 's Info
# Done!!!
# ==============================================================================
#
# Loading... Farfetch'd 's Data
# Writting... Farfetch'd 's Info
# Done!!!
# ==============================================================================
#
# Loading... Doduo 's Data
# Writting... Doduo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dodrio 's Data
# Writting... Dodrio 's Info
# Done!!!
# ==============================================================================
#
# Loading... Seel 's Data
# Writting... Seel 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dewgong 's Data
# Writting... Dewgong 's Info
# Done!!!
# ==============================================================================
#
# Loading... Grimer 's Data
# Writting... Grimer 's Info
# Done!!!
# ==============================================================================
#
# Loading... Grimer 's Data
# Writting... Grimer 's Info
# Done!!!
# ==============================================================================
#
# Loading... Muk 's Data
# Writting... Muk 's Info
# Done!!!
# ==============================================================================
#
# Loading... Muk 's Data
# Writting... Muk 's Info
# Done!!!
# ==============================================================================
#
# Loading... Shellder 's Data
# Writting... Shellder 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cloyster 's Data
# Writting... Cloyster 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gastly 's Data
# Writting... Gastly 's Info
# Done!!!
# ==============================================================================
#
# Loading... Haunter 's Data
# Writting... Haunter 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gengar 's Data
# Writting... Gengar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Onix 's Data
# Writting... Onix 's Info
# Done!!!
# ==============================================================================
#
# Loading... Drowzee 's Data
# Writting... Drowzee 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hypno 's Data
# Writting... Hypno 's Info
# Done!!!
# ==============================================================================
#
# Loading... Krabby 's Data
# Writting... Krabby 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kingler 's Data
# Writting... Kingler 's Info
# Done!!!
# ==============================================================================
#
# Loading... Voltorb 's Data
# Writting... Voltorb 's Info
# Done!!!
# ==============================================================================
#
# Loading... Electrode 's Data
# Writting... Electrode 's Info
# Done!!!
# ==============================================================================
#
# Loading... Exeggcute 's Data
# Writting... Exeggcute 's Info
# Done!!!
# ==============================================================================
#
# Loading... Exeggutor 's Data
# Writting... Exeggutor 's Info
# Done!!!
# ==============================================================================
#
# Loading... Exeggutor 's Data
# Writting... Exeggutor 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cubone 's Data
# Writting... Cubone 's Info
# Done!!!
# ==============================================================================
#
# Loading... Marowak 's Data
# Writting... Marowak 's Info
# Done!!!
# ==============================================================================
#
# Loading... Marowak 's Data
# Writting... Marowak 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hitmonlee 's Data
# Writting... Hitmonlee 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hitmonchan 's Data
# Writting... Hitmonchan 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lickitung 's Data
# Writting... Lickitung 's Info
# Done!!!
# ==============================================================================
#
# Loading... Koffing 's Data
# Writting... Koffing 's Info
# Done!!!
# ==============================================================================
#
# Loading... Weezing 's Data
# Writting... Weezing 's Info
# Done!!!
# ==============================================================================
#
# Loading... Weezing 's Data
# Writting... Weezing 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rhyhorn 's Data
# Writting... Rhyhorn 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rhydon 's Data
# Writting... Rhydon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Chansey 's Data
# Writting... Chansey 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tangela 's Data
# Writting... Tangela 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kangaskhan 's Data
# Writting... Kangaskhan 's Info
# Done!!!
# ==============================================================================
#
# Loading... Horsea 's Data
# Writting... Horsea 's Info
# Done!!!
# ==============================================================================
#
# Loading... Seadra 's Data
# Writting... Seadra 's Info
# Done!!!
# ==============================================================================
#
# Loading... Goldeen 's Data
# Writting... Goldeen 's Info
# Done!!!
# ==============================================================================
#
# Loading... Seaking 's Data
# Writting... Seaking 's Info
# Done!!!
# ==============================================================================
#
# Loading... Staryu 's Data
# Writting... Staryu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Starmie 's Data
# Writting... Starmie 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mr. Mime 's Data
# Writting... Mr. Mime 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mr. Mime 's Data
# Writting... Mr. Mime 's Info
# Done!!!
# ==============================================================================
#
# Loading... Scyther 's Data
# Writting... Scyther 's Info
# Done!!!
# ==============================================================================
#
# Loading... Jynx 's Data
# Writting... Jynx 's Info
# Done!!!
# ==============================================================================
#
# Loading... Electabuzz 's Data
# Writting... Electabuzz 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magmar 's Data
# Writting... Magmar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pinsir 's Data
# Writting... Pinsir 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tauros 's Data
# Writting... Tauros 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magikarp 's Data
# Writting... Magikarp 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gyarados 's Data
# Writting... Gyarados 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lapras 's Data
# Writting... Lapras 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ditto 's Data
# Writting... Ditto 's Info
# Done!!!
# ==============================================================================
#
# Loading... Eevee 's Data
# Writting... Eevee 's Info
# Done!!!
# ==============================================================================
#
# Loading... Vaporeon 's Data
# Writting... Vaporeon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Jolteon 's Data
# Writting... Jolteon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Flareon 's Data
# Writting... Flareon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Porygon 's Data
# Writting... Porygon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Omanyte 's Data
# Writting... Omanyte 's Info
# Done!!!
# ==============================================================================
#
# Loading... Omastar 's Data
# Writting... Omastar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kabuto 's Data
# Writting... Kabuto 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kabutops 's Data
# Writting... Kabutops 's Info
# Done!!!
# ==============================================================================
#
# Loading... Aerodactyl 's Data
# Writting... Aerodactyl 's Info
# Done!!!
# ==============================================================================
#
# Loading... Snorlax 's Data
# Writting... Snorlax 's Info
# Done!!!
# ==============================================================================
#
# Loading... Articuno 's Data
# Writting... Articuno 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zapdos 's Data
# Writting... Zapdos 's Info
# Done!!!
# ==============================================================================
#
# Loading... Moltres 's Data
# Writting... Moltres 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dratini 's Data
# Writting... Dratini 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dragonair 's Data
# Writting... Dragonair 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dragonite 's Data
# Writting... Dragonite 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mewtwo 's Data
# Writting... Mewtwo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mew 's Data
# Writting... Mew 's Info
# Done!!!
# ==============================================================================
#
# Loading... Chikorita 's Data
# Writting... Chikorita 's Info
# Done!!!
# ==============================================================================
#
# Loading... Bayleef 's Data
# Writting... Bayleef 's Info
# Done!!!
# ==============================================================================
#
# Loading... Meganium 's Data
# Writting... Meganium 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cyndaquil 's Data
# Writting... Cyndaquil 's Info
# Done!!!
# ==============================================================================
#
# Loading... Quilava 's Data
# Writting... Quilava 's Info
# Done!!!
# ==============================================================================
#
# Loading... Typhlosion 's Data
# Writting... Typhlosion 's Info
# Done!!!
# ==============================================================================
#
# Loading... Totodile 's Data
# Writting... Totodile 's Info
# Done!!!
# ==============================================================================
#
# Loading... Croconaw 's Data
# Writting... Croconaw 's Info
# Done!!!
# ==============================================================================
#
# Loading... Feraligatr 's Data
# Writting... Feraligatr 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sentret 's Data
# Writting... Sentret 's Info
# Done!!!
# ==============================================================================
#
# Loading... Furret 's Data
# Writting... Furret 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hoothoot 's Data
# Writting... Hoothoot 's Info
# Done!!!
# ==============================================================================
#
# Loading... Noctowl 's Data
# Writting... Noctowl 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ledyba 's Data
# Writting... Ledyba 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ledian 's Data
# Writting... Ledian 's Info
# Done!!!
# ==============================================================================
#
# Loading... Spinarak 's Data
# Writting... Spinarak 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ariados 's Data
# Writting... Ariados 's Info
# Done!!!
# ==============================================================================
#
# Loading... Crobat 's Data
# Writting... Crobat 's Info
# Done!!!
# ==============================================================================
#
# Loading... Chinchou 's Data
# Writting... Chinchou 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lanturn 's Data
# Writting... Lanturn 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pichu 's Data
# Writting... Pichu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cleffa 's Data
# Writting... Cleffa 's Info
# Done!!!
# ==============================================================================
#
# Loading... Igglybuff 's Data
# Writting... Igglybuff 's Info
# Done!!!
# ==============================================================================
#
# Loading... Togepi 's Data
# Writting... Togepi 's Info
# Done!!!
# ==============================================================================
#
# Loading... Togetic 's Data
# Writting... Togetic 's Info
# Done!!!
# ==============================================================================
#
# Loading... Natu 's Data
# Writting... Natu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Xatu 's Data
# Writting... Xatu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mareep 's Data
# Writting... Mareep 's Info
# Done!!!
# ==============================================================================
#
# Loading... Flaaffy 's Data
# Writting... Flaaffy 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ampharos 's Data
# Writting... Ampharos 's Info
# Done!!!
# ==============================================================================
#
# Loading... Bellossom 's Data
# Writting... Bellossom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Marill 's Data
# Writting... Marill 's Info
# Done!!!
# ==============================================================================
#
# Loading... Azumarill 's Data
# Writting... Azumarill 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sudowoodo 's Data
# Writting... Sudowoodo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Politoed 's Data
# Writting... Politoed 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hoppip 's Data
# Writting... Hoppip 's Info
# Done!!!
# ==============================================================================
#
# Loading... Skiploom 's Data
# Writting... Skiploom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Jumpluff 's Data
# Writting... Jumpluff 's Info
# Done!!!
# ==============================================================================
#
# Loading... Aipom 's Data
# Writting... Aipom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sunkern 's Data
# Writting... Sunkern 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sunflora 's Data
# Writting... Sunflora 's Info
# Done!!!
# ==============================================================================
#
# Loading... Yanma 's Data
# Writting... Yanma 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wooper 's Data
# Writting... Wooper 's Info
# Done!!!
# ==============================================================================
#
# Loading... Quagsire 's Data
# Writting... Quagsire 's Info
# Done!!!
# ==============================================================================
#
# Loading... Espeon 's Data
# Writting... Espeon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Umbreon 's Data
# Writting... Umbreon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Murkrow 's Data
# Writting... Murkrow 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slowking 's Data
# Writting... Slowking 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slowking 's Data
# Writting... Slowking 's Info
# Done!!!
# ==============================================================================
#
# Loading... Misdreavus 's Data
# Writting... Misdreavus 's Info
# Done!!!
# ==============================================================================
#
# Loading... Unown 's Data
# Writting... Unown 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wobbuffet 's Data
# Writting... Wobbuffet 's Info
# Done!!!
# ==============================================================================
#
# Loading... Girafarig 's Data
# Writting... Girafarig 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pineco 's Data
# Writting... Pineco 's Info
# Done!!!
# ==============================================================================
#
# Loading... Forretress 's Data
# Writting... Forretress 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dunsparce 's Data
# Writting... Dunsparce 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gligar 's Data
# Writting... Gligar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Steelix 's Data
# Writting... Steelix 's Info
# Done!!!
# ==============================================================================
#
# Loading... Snubbull 's Data
# Writting... Snubbull 's Info
# Done!!!
# ==============================================================================
#
# Loading... Granbull 's Data
# Writting... Granbull 's Info
# Done!!!
# ==============================================================================
#
# Loading... Qwilfish 's Data
# Writting... Qwilfish 's Info
# Done!!!
# ==============================================================================
#
# Loading... Scizor 's Data
# Writting... Scizor 's Info
# Done!!!
# ==============================================================================
#
# Loading... Shuckle 's Data
# Writting... Shuckle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Heracross 's Data
# Writting... Heracross 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sneasel 's Data
# Writting... Sneasel 's Info
# Done!!!
# ==============================================================================
#
# Loading... Teddiursa 's Data
# Writting... Teddiursa 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ursaring 's Data
# Writting... Ursaring 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slugma 's Data
# Writting... Slugma 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magcargo 's Data
# Writting... Magcargo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Swinub 's Data
# Writting... Swinub 's Info
# Done!!!
# ==============================================================================
#
# Loading... Piloswine 's Data
# Writting... Piloswine 's Info
# Done!!!
# ==============================================================================
#
# Loading... Corsola 's Data
# Writting... Corsola 's Info
# Done!!!
# ==============================================================================
#
# Loading... Corsola 's Data
# Writting... Corsola 's Info
# Done!!!
# ==============================================================================
#
# Loading... Remoraid 's Data
# Writting... Remoraid 's Info
# Done!!!
# ==============================================================================
#
# Loading... Octillery 's Data
# Writting... Octillery 's Info
# Done!!!
# ==============================================================================
#
# Loading... Delibird 's Data
# Writting... Delibird 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mantine 's Data
# Writting... Mantine 's Info
# Done!!!
# ==============================================================================
#
# Loading... Skarmory 's Data
# Writting... Skarmory 's Info
# Done!!!
# ==============================================================================
#
# Loading... Houndour 's Data
# Writting... Houndour 's Info
# Done!!!
# ==============================================================================
#
# Loading... Houndoom 's Data
# Writting... Houndoom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kingdra 's Data
# Writting... Kingdra 's Info
# Done!!!
# ==============================================================================
#
# Loading... Phanpy 's Data
# Writting... Phanpy 's Info
# Done!!!
# ==============================================================================
#
# Loading... Donphan 's Data
# Writting... Donphan 's Info
# Done!!!
# ==============================================================================
#
# Loading... Porygon2 's Data
# Writting... Porygon2 's Info
# Done!!!
# ==============================================================================
#
# Loading... Stantler 's Data
# Writting... Stantler 's Info
# Done!!!
# ==============================================================================
#
# Loading... Smeargle 's Data
# Writting... Smeargle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tyrogue 's Data
# Writting... Tyrogue 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hitmontop 's Data
# Writting... Hitmontop 's Info
# Done!!!
# ==============================================================================
#
# Loading... Smoochum 's Data
# Writting... Smoochum 's Info
# Done!!!
# ==============================================================================
#
# Loading... Elekid 's Data
# Writting... Elekid 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magby 's Data
# Writting... Magby 's Info
# Done!!!
# ==============================================================================
#
# Loading... Miltank 's Data
# Writting... Miltank 's Info
# Done!!!
# ==============================================================================
#
# Loading... Blissey 's Data
# Writting... Blissey 's Info
# Done!!!
# ==============================================================================
#
# Loading... Raikou 's Data
# Writting... Raikou 's Info
# Done!!!
# ==============================================================================
#
# Loading... Entei 's Data
# Writting... Entei 's Info
# Done!!!
# ==============================================================================
#
# Loading... Suicune 's Data
# Writting... Suicune 's Info
# Done!!!
# ==============================================================================
#
# Loading... Larvitar 's Data
# Writting... Larvitar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pupitar 's Data
# Writting... Pupitar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tyranitar 's Data
# Writting... Tyranitar 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lugia 's Data
# Writting... Lugia 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ho-Oh 's Data
# Writting... Ho-Oh 's Info
# Done!!!
# ==============================================================================
#
# Loading... Celebi 's Data
# Writting... Celebi 's Info
# Done!!!
# ==============================================================================
#
# Loading... Treecko 's Data
# Writting... Treecko 's Info
# Done!!!
# ==============================================================================
#
# Loading... Grovyle 's Data
# Writting... Grovyle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sceptile 's Data
# Writting... Sceptile 's Info
# Done!!!
# ==============================================================================
#
# Loading... Torchic 's Data
# Writting... Torchic 's Info
# Done!!!
# ==============================================================================
#
# Loading... Combusken 's Data
# Writting... Combusken 's Info
# Done!!!
# ==============================================================================
#
# Loading... Blaziken 's Data
# Writting... Blaziken 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mudkip 's Data
# Writting... Mudkip 's Info
# Done!!!
# ==============================================================================
#
# Loading... Marshtomp 's Data
# Writting... Marshtomp 's Info
# Done!!!
# ==============================================================================
#
# Loading... Swampert 's Data
# Writting... Swampert 's Info
# Done!!!
# ==============================================================================
#
# Loading... Poochyena 's Data
# Writting... Poochyena 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mightyena 's Data
# Writting... Mightyena 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zigzagoon 's Data
# Writting... Zigzagoon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zigzagoon 's Data
# Writting... Zigzagoon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Linoone 's Data
# Writting... Linoone 's Info
# Done!!!
# ==============================================================================
#
# Loading... Linoone 's Data
# Writting... Linoone 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wurmple 's Data
# Writting... Wurmple 's Info
# Done!!!
# ==============================================================================
#
# Loading... Silcoon 's Data
# Writting... Silcoon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Beautifly 's Data
# Writting... Beautifly 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cascoon 's Data
# Writting... Cascoon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dustox 's Data
# Writting... Dustox 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lotad 's Data
# Writting... Lotad 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lombre 's Data
# Writting... Lombre 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ludicolo 's Data
# Writting... Ludicolo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Seedot 's Data
# Writting... Seedot 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nuzleaf 's Data
# Writting... Nuzleaf 's Info
# Done!!!
# ==============================================================================
#
# Loading... Shiftry 's Data
# Writting... Shiftry 's Info
# Done!!!
# ==============================================================================
#
# Loading... Taillow 's Data
# Writting... Taillow 's Info
# Done!!!
# ==============================================================================
#
# Loading... Swellow 's Data
# Writting... Swellow 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wingull 's Data
# Writting... Wingull 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pelipper 's Data
# Writting... Pelipper 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ralts 's Data
# Writting... Ralts 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kirlia 's Data
# Writting... Kirlia 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gardevoir 's Data
# Writting... Gardevoir 's Info
# Done!!!
# ==============================================================================
#
# Loading... Surskit 's Data
# Writting... Surskit 's Info
# Done!!!
# ==============================================================================
#
# Loading... Masquerain 's Data
# Writting... Masquerain 's Info
# Done!!!
# ==============================================================================
#
# Loading... Shroomish 's Data
# Writting... Shroomish 's Info
# Done!!!
# ==============================================================================
#
# Loading... Breloom 's Data
# Writting... Breloom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slakoth 's Data
# Writting... Slakoth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Vigoroth 's Data
# Writting... Vigoroth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Slaking 's Data
# Writting... Slaking 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nincada 's Data
# Writting... Nincada 's Info
# Done!!!
# ==============================================================================
#
# Loading... Ninjask 's Data
# Writting... Ninjask 's Info
# Done!!!
# ==============================================================================
#
# Loading... Shedinja 's Data
# Writting... Shedinja 's Info
# Done!!!
# ==============================================================================
#
# Loading... Whismur 's Data
# Writting... Whismur 's Info
# Done!!!
# ==============================================================================
#
# Loading... Loudred 's Data
# Writting... Loudred 's Info
# Done!!!
# ==============================================================================
#
# Loading... Exploud 's Data
# Writting... Exploud 's Info
# Done!!!
# ==============================================================================
#
# Loading... Makuhita 's Data
# Writting... Makuhita 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hariyama 's Data
# Writting... Hariyama 's Info
# Done!!!
# ==============================================================================
#
# Loading... Azurill 's Data
# Writting... Azurill 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nosepass 's Data
# Writting... Nosepass 's Info
# Done!!!
# ==============================================================================
#
# Loading... Skitty 's Data
# Writting... Skitty 's Info
# Done!!!
# ==============================================================================
#
# Loading... Delcatty 's Data
# Writting... Delcatty 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sableye 's Data
# Writting... Sableye 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mawile 's Data
# Writting... Mawile 's Info
# Done!!!
# ==============================================================================
#
# Loading... Aron 's Data
# Writting... Aron 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lairon 's Data
# ...
#
# Loading... Kommo-o 's Data
# Writting... Kommo-o 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tapu Koko 's Data
# Writting... Tapu Koko 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tapu Lele 's Data
# Writting... Tapu Lele 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tapu Bulu 's Data
# Writting... Tapu Bulu 's Info
# Done!!!
# ==============================================================================
#
# Loading... Tapu Fini 's Data
# Writting... Tapu Fini 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cosmog 's Data
# Writting... Cosmog 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cosmoem 's Data
# Writting... Cosmoem 's Info
# Done!!!
# ==============================================================================
#
# Loading... Solgaleo 's Data
# Writting... Solgaleo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Lunala 's Data
# Writting... Lunala 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nihilego 's Data
# Writting... Nihilego 's Info
# Done!!!
# ==============================================================================
#
# Loading... Buzzwole 's Data
# Writting... Buzzwole 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pheromosa 's Data
# Writting... Pheromosa 's Info
# Done!!!
# ==============================================================================
#
# Loading... Xurkitree 's Data
# Writting... Xurkitree 's Info
# Done!!!
# ==============================================================================
#
# Loading... Celesteela 's Data
# Writting... Celesteela 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kartana 's Data
# Writting... Kartana 's Info
# Done!!!
# ==============================================================================
#
# Loading... Guzzlord 's Data
# Writting... Guzzlord 's Info
# Done!!!
# ==============================================================================
#
# Loading... Necrozma 's Data
# Writting... Necrozma 's Info
# Done!!!
# ==============================================================================
#
# Loading... Magearna 's Data
# Writting... Magearna 's Info
# Done!!!
# ==============================================================================
#
# Loading... Marshadow 's Data
# Writting... Marshadow 's Info
# Done!!!
# ==============================================================================
#
# Loading... Poipole 's Data
# Writting... Poipole 's Info
# Done!!!
# ==============================================================================
#
# Loading... Naganadel 's Data
# Writting... Naganadel 's Info
# Done!!!
# ==============================================================================
#
# Loading... Stakataka 's Data
# Writting... Stakataka 's Info
# Done!!!
# ==============================================================================
#
# Loading... Blacephalon 's Data
# Writting... Blacephalon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zeraora 's Data
# Writting... Zeraora 's Info
# Done!!!
# ==============================================================================
#
# Loading... Meltan 's Data
# Writting... Meltan 's Info
# Done!!!
# ==============================================================================
#
# Loading... Melmetal 's Data
# Writting... Melmetal 's Info
# Done!!!
# ==============================================================================
#
# Loading... Grookey 's Data
# Writting... Grookey 's Info
# Done!!!
# ==============================================================================
#
# Loading... Thwackey 's Data
# Writting... Thwackey 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rillaboom 's Data
# Writting... Rillaboom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Scorbunny 's Data
# Writting... Scorbunny 's Info
# Done!!!
# ==============================================================================
#
# Loading... Raboot 's Data
# Writting... Raboot 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cinderace 's Data
# Writting... Cinderace 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sobble 's Data
# Writting... Sobble 's Info
# Done!!!
# ==============================================================================
#
# Loading... Drizzile 's Data
# Writting... Drizzile 's Info
# Done!!!
# ==============================================================================
#
# Loading... Inteleon 's Data
# Writting... Inteleon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Skwovet 's Data
# Writting... Skwovet 's Info
# Done!!!
# ==============================================================================
#
# Loading... Greedent 's Data
# Writting... Greedent 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rookidee 's Data
# Writting... Rookidee 's Info
# Done!!!
# ==============================================================================
#
# Loading... Corvisquire 's Data
# Writting... Corvisquire 's Info
# Done!!!
# ==============================================================================
#
# Loading... Corviknight 's Data
# Writting... Corviknight 's Info
# Done!!!
# ==============================================================================
#
# Loading... Blipbug 's Data
# Writting... Blipbug 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dottler 's Data
# Writting... Dottler 's Info
# Done!!!
# ==============================================================================
#
# Loading... Orbeetle 's Data
# Writting... Orbeetle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Nickit 's Data
# Writting... Nickit 's Info
# Done!!!
# ==============================================================================
#
# Loading... Thievul 's Data
# Writting... Thievul 's Info
# Done!!!
# ==============================================================================
#
# Loading... Gossifleur 's Data
# Writting... Gossifleur 's Info
# Done!!!
# ==============================================================================
#
# Loading... Eldegoss 's Data
# Writting... Eldegoss 's Info
# Done!!!
# ==============================================================================
#
# Loading... Wooloo 's Data
# Writting... Wooloo 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dubwool 's Data
# Writting... Dubwool 's Info
# Done!!!
# ==============================================================================
#
# Loading... Chewtle 's Data
# Writting... Chewtle 's Info
# Done!!!
# ==============================================================================
#
# Loading... Drednaw 's Data
# Writting... Drednaw 's Info
# Done!!!
# ==============================================================================
#
# Loading... Yamper 's Data
# Writting... Yamper 's Info
# Done!!!
# ==============================================================================
#
# Loading... Boltund 's Data
# Writting... Boltund 's Info
# Done!!!
# ==============================================================================
#
# Loading... Rolycoly 's Data
# Writting... Rolycoly 's Info
# Done!!!
# ==============================================================================
#
# Loading... Carkol 's Data
# Writting... Carkol 's Info
# Done!!!
# ==============================================================================
#
# Loading... Coalossal 's Data
# Writting... Coalossal 's Info
# Done!!!
# ==============================================================================
#
# Loading... Applin 's Data
# Writting... Applin 's Info
# Done!!!
# ==============================================================================
#
# Loading... Flapple 's Data
# Writting... Flapple 's Info
# Done!!!
# ==============================================================================
#
# Loading... Appletun 's Data
# Writting... Appletun 's Info
# Done!!!
# ==============================================================================
#
# Loading... Silicobra 's Data
# Writting... Silicobra 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sandaconda 's Data
# Writting... Sandaconda 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cramorant 's Data
# Writting... Cramorant 's Info
# Done!!!
# ==============================================================================
#
# Loading... Arrokuda 's Data
# Writting... Arrokuda 's Info
# Done!!!
# ==============================================================================
#
# Loading... Barraskewda 's Data
# Writting... Barraskewda 's Info
# Done!!!
# ==============================================================================
#
# Loading... Toxel 's Data
# Writting... Toxel 's Info
# Done!!!
# ==============================================================================
#
# Loading... Toxtricity 's Data
# Writting... Toxtricity 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sizzlipede 's Data
# Writting... Sizzlipede 's Info
# Done!!!
# ==============================================================================
#
# Loading... Centiskorch 's Data
# Writting... Centiskorch 's Info
# Done!!!
# ==============================================================================
#
# Loading... Clobbopus 's Data
# Writting... Clobbopus 's Info
# Done!!!
# ==============================================================================
#
# Loading... Grapploct 's Data
# Writting... Grapploct 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sinistea 's Data
# Writting... Sinistea 's Info
# Done!!!
# ==============================================================================
#
# Loading... Polteageist 's Data
# Writting... Polteageist 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hatenna 's Data
# Writting... Hatenna 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hattrem 's Data
# Writting... Hattrem 's Info
# Done!!!
# ==============================================================================
#
# Loading... Hatterene 's Data
# Writting... Hatterene 's Info
# Done!!!
# ==============================================================================
#
# Loading... Impidimp 's Data
# Writting... Impidimp 's Info
# Done!!!
# ==============================================================================
#
# Loading... Morgrem 's Data
# Writting... Morgrem 's Info
# Done!!!
# ==============================================================================
#
# Loading... Grimmsnarl 's Data
# Writting... Grimmsnarl 's Info
# Done!!!
# ==============================================================================
#
# Loading... Obstagoon 's Data
# Writting... Obstagoon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Perrserker 's Data
# Writting... Perrserker 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cursola 's Data
# Writting... Cursola 's Info
# Done!!!
# ==============================================================================
#
# Loading... Sirfetch'd 's Data
# Writting... Sirfetch'd 's Info
# Done!!!
# ==============================================================================
#
# Loading... Mr. Rime 's Data
# Writting... Mr. Rime 's Info
# Done!!!
# ==============================================================================
#
# Loading... Runerigus 's Data
# Writting... Runerigus 's Info
# Done!!!
# ==============================================================================
#
# Loading... Milcery 's Data
# Writting... Milcery 's Info
# Done!!!
# ==============================================================================
#
# Loading... Alcremie 's Data
# Writting... Alcremie 's Info
# Done!!!
# ==============================================================================
#
# Loading... Falinks 's Data
# Writting... Falinks 's Info
# Done!!!
# ==============================================================================
#
# Loading... Pincurchin 's Data
# Writting... Pincurchin 's Info
# Done!!!
# ==============================================================================
#
# Loading... Snom 's Data
# Writting... Snom 's Info
# Done!!!
# ==============================================================================
#
# Loading... Frosmoth 's Data
# Writting... Frosmoth 's Info
# Done!!!
# ==============================================================================
#
# Loading... Stonjourner 's Data
# Writting... Stonjourner 's Info
# Done!!!
# ==============================================================================
#
# Loading... Eiscue 's Data
# Writting... Eiscue 's Info
# Done!!!
# ==============================================================================
#
# Loading... Indeedee 's Data
# Writting... Indeedee 's Info
# Done!!!
# ==============================================================================
#
# Loading... Morpeko 's Data
# Writting... Morpeko 's Info
# Done!!!
# ==============================================================================
#
# Loading... Cufant 's Data
# Writting... Cufant 's Info
# Done!!!
# ==============================================================================
#
# Loading... Copperajah 's Data
# Writting... Copperajah 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dracozolt 's Data
# Writting... Dracozolt 's Info
# Done!!!
# ==============================================================================
#
# Loading... Arctozolt 's Data
# Writting... Arctozolt 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dracovish 's Data
# Writting... Dracovish 's Info
# Done!!!
# ==============================================================================
#
# Loading... Arctovish 's Data
# Writting... Arctovish 's Info
# Done!!!
# ==============================================================================
#
# Loading... Duraludon 's Data
# Writting... Duraludon 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dreepy 's Data
# Writting... Dreepy 's Info
# Done!!!
# ==============================================================================
#
# Loading... Drakloak 's Data
# Writting... Drakloak 's Info
# Done!!!
# ==============================================================================
#
# Loading... Dragapult 's Data
# Writting... Dragapult 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zacian 's Data
# Writting... Zacian 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zacian 's Data
# Writting... Zacian 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zamazenta 's Data
# Writting... Zamazenta 's Info
# Done!!!
# ==============================================================================
#
# Loading... Zamazenta 's Data
# Writting... Zamazenta 's Info
# Done!!!
# ==============================================================================
#
# Loading... Eternatus 's Data
# Writting... Eternatus 's Info
# Done!!!
# ==============================================================================
#
# Loading... Kubfu 's Data
# Loading... Urshifu 's Data
# Loading... Urshifu 's Data
# Loading... Calyrex 's Data
# Loading... Zarude 's Data

# %%
f.close()

# %%
data=pd.read_csv('pokemon_data.csv')
data.head()
# Out:
#     Kdex   Ndex        Name  Type1   Type2  \
# 0   #001   #001   Bulbasaur  Grass  Poison
# 1   #002   #002     Ivysaur  Grass  Poison
# 2   #003   #003    Venusaur  Grass  Poison
# 3   #004   #004  Charmander   Fire    Null
# 4   #005   #005  Charmeleon   Fire    Null
#
#                                                 Link  HP  ATK  DEF  SP_ATK  \
# 0  https://bulbapedia.bulbagarden.net//wiki/Bulba...  45   49   49      65
# 1  https://bulbapedia.bulbagarden.net//wiki/Ivysa...  60   62   63      80
# 2  https://bulbapedia.bulbagarden.net//wiki/Venus...  80   82   83     100
# 3  https://bulbapedia.bulbagarden.net//wiki/Charm...  39   52   43      60
# 4  https://bulbapedia.bulbagarden.net//wiki/Charm...  58   64   58      80
#
#    SP_DEF  SPD                                Damaged Normally by  \
# 0      65   45  ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_...
# 1      80   60  ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_...
# 2     100   80  ['Normal_1×', 'Poison_1×', 'Ground_1×', 'Rock_...
# 3      50   65  ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poi...
# 4      65   80  ['Normal_1×', 'Fighting_1×', 'Flying_1×', 'Poi...
#
#                                             Weak to  Immue to  \
# 0  ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']  ['None']
# 1  ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']  ['None']
# 2  ['Flying_2×', 'Fire_2×', 'Psychic_2×', 'Ice_2×']  ['None']
# 3              ['Ground_2×', 'Rock_2×', 'Water_2×']  ['None']
# 4              ['Ground_2×', 'Rock_2×', 'Water_2×']  ['None']
#
#                                          Resisant to
# 0  ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Elect...
# 1  ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Elect...
# 2  ['Fighting_½×', 'Water_½×', 'Grass_¼×', 'Elect...
# 3  ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', ...
# 4  ['Bug_½×', 'Steel_½×', 'Fire_½×', 'Grass_½×', ...
